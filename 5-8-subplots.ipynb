# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

a = sns.load_dataset('tips')
#sns.relplot( x = 'total_bill', y = 'tip', hue = 'smoker', col = 'time', data = a)
#sns.relplot( x = 'total_bill', y = 'tip', hue = 'time', col = 'smoker', data = a)
#sns.relplot( x = 'total_bill', y = 'tip', style = 'smoker', col = 'time', data = a)
#sns.relplot( x = 'total_bill', y = 'tip', hue = 'smoker', col = 'size', data = a, col_wrap = 3)
sns.relplot( x = 'total_bill', y = 'tip', hue = 'smoker', col = 'size', data = a, col_wrap = 3, style = 'time')
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
