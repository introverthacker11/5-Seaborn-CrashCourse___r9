# %%
# line plot

import seaborn as sns

a = sns.load_dataset('tips').head(6)
a,sns.relplot( x = 'total_bill', y = 'tip', data = a, hue = 'sex', kind = 'line', marker = 'o')
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# (   total_bill   tip     sex smoker  day    time  size
#  0       16.99  1.01  Female     No  Sun  Dinner     2
#  1       10.34  1.66    Male     No  Sun  Dinner     3
#  2       21.01  3.50    Male     No  Sun  Dinner     3
#  3       23.68  3.31    Male     No  Sun  Dinner     2
#  4       24.59  3.61  Female     No  Sun  Dinner     4
#  5       25.29  4.71    Male     No  Sun  Dinner     4,
#  <seaborn.axisgrid.FacetGrid at 0x2058f628390>)

# %%
# line plot

import pandas as pd
import seaborn as sns

a = pd.read_csv('groupby(csvfile8).csv')
a, sns.relplot( x = 'College', y = 'Age', data = a, kind = 'line', hue = 'Department')
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# (  College    Department  Student  Rank  Height(foot.inch)  Age
#  0     CAA       Pre-Eng   Rayyan     1                6.4   19
#  1     COD  Comp.Science    Ahmed     4                6.1   20
#  2     CAA       Pre-Eng    Qutub     2                5.8   20
#  3     FDC       Pre-Eng      Ali     8                5.9   21
#  4     COD  Comp.Science    Azhar    10                5.5   19
#  5     COD       Pre-Eng   Rizwan     3                6.0   23
#  6    PAF    Pre-Medical   Junaid     5                6.0   23
#  7     CAA   Pre-Medical  Shaheer     6                5.8   19
#  8     CAA  Comp.Science   Asshad     9                5.9   21
#  9     FDC       Pre-Eng    Abdul     7                5.7   20,
#  <seaborn.axisgrid.FacetGrid at 0x20591d64950>)

# %%
# line plot
# estimator

import pandas as pd
import seaborn as sns

a = pd.read_csv('groupby(csvfile8).csv')
a, sns.relplot( x = 'College', y = 'Age', data = a, kind = 'line', estimator = None)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# (  College    Department  Student  Rank  Height(foot.inch)  Age
#  0     CAA       Pre-Eng   Rayyan     1                6.4   19
#  1     COD  Comp.Science    Ahmed     4                6.1   20
#  2     CAA       Pre-Eng    Qutub     2                5.8   20
#  3     FDC       Pre-Eng      Ali     8                5.9   21
#  4     COD  Comp.Science    Azhar    10                5.5   19
#  5     COD       Pre-Eng   Rizwan     3                6.0   23
#  6    PAF    Pre-Medical   Junaid     5                6.0   23
#  7     CAA   Pre-Medical  Shaheer     6                5.8   19
#  8     CAA  Comp.Science   Asshad     9                5.9   21
#  9     FDC       Pre-Eng    Abdul     7                5.7   20,
#  <seaborn.axisgrid.FacetGrid at 0x20593372510>)
